# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df=pd. read_csv('loan_data.xls')
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
# data viewing
df.head(10)
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
# 5        21.0        female      High School        12951.0               0
# 6        26.0        female         Bachelor        93471.0               1
# 7        24.0        female      High School        95550.0               5
# 8        24.0        female        Associate       100684.0               3
# 9        21.0        female      High School        12739.0               0
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# ...

# %%
# data viewing
df.tail(10)
# Out:
#        person_age person_gender person_education  person_income  \
# 44990        31.0          male           Master       136832.0
# 44991        24.0          male      High School        37786.0
# 44992        23.0        female         Bachelor        40925.0
# 44993        27.0        female      High School        35512.0
# 44994        24.0        female        Associate        31924.0
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 44990               9                  RENT    12319.0           PERSONAL
# 44991               0              MORTGAGE    13500.0          EDUCATION
# ...

# %%
df. sample()
# Out:
#       person_age person_gender person_education  person_income  \
# 3985        23.0        female        Associate        62871.0
#
#       person_emp_exp person_home_ownership  loan_amnt loan_intent  \
# 3985               3                  RENT     4000.0    PERSONAL
#
#       loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 3985           9.91                 0.06                         3.0
#
#       credit_score previous_loan_defaults_on_file  loan_status
# 3985           547                             No            0

# %%
df.dtypes
# Out:
# person_age                        float64
# person_gender                      object
# person_education                   object
# person_income                     float64
# person_emp_exp                      int64
# person_home_ownership              object
# loan_amnt                         float64
# loan_intent                        object
# loan_int_rate                     float64
# loan_percent_income               float64
# cb_person_cred_hist_length        float64
# credit_score                        int64
# previous_loan_defaults_on_file     object
# loan_status                         int64
# dtype: object

# %%
df. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
# ...

# %%
df['person_age']
# Out:
# 0        22.0
# 1        21.0
# 2        25.0
# 3        23.0
# 4        24.0
#          ...
# 44995    27.0
# 44996    37.0
# 44997    33.0
# 44998    29.0
# 44999    24.0
# Name: person_age, Length: 45000, dtype: float64

# %%
df['person_age'].max()
# Out:
# np.float64(144.0)

# %%
df. describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# ...

# %%
#find missing value
df. isnull().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# loan_percent_income               0
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %%
df. isnull()
# Out:
#        person_age  person_gender  person_education  person_income  \
# 0           False          False             False          False
# 1           False          False             False          False
# 2           False          False             False          False
# 3           False          False             False          False
# 4           False          False             False          False
# ...           ...            ...               ...            ...
# 44995       False          False             False          False
# 44996       False          False             False          False
# 44997       False          False             False          False
# 44998       False          False             False          False
# 44999       False          False             False          False
#
#        person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# 0               False                  False      False        False
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['person_education'].value_counts()
# Out:
# person_education
# Bachelor       13399
# Associate      12028
# High School    11972
# Master          6980
# Doctorate        621
# Name: count, dtype: int64

# %%
df['person_education'].unique()
# Out:
# array(['Master', 'High School', 'Bachelor', 'Associate', 'Doctorate'],
#       dtype=object)

# %%
df['person_education'].nunique()
# Out:
# 5

# %%
df['person_education'].replace({'Master':0, 'High School':1, 'Bachelor':2, 'Associate':3, 'Doctorate':4})
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2300\1793655016.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['person_education'].replace({'Master':0, 'High School':1, 'Bachelor':2, 'Associate':3, 'Doctorate':4})
# 0        0
# 1        1
# 2        1
# 3        2
# 4        0
#         ..
# 44995    3
# 44996    3
# 44997    3
# 44998    2
# 44999    1
# Name: person_education, Length: 45000, dtype: int64

# %%
df['person_education']=df['person_education'].replace({'Master':0, 'High School':1, 'Bachelor':2, 'Associate':3, 'Doctorate':4})
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2300\2307126300.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['person_education']=df['person_education'].replace({'Master':0, 'High School':1, 'Bachelor':2, 'Associate':3, 'Doctorate':4})

# %%
df['person_age']=df['person_age'].astype(int)

# %%
df.dtypes
# Out:
# person_age                          int64
# person_gender                      object
# person_education                    int64
# person_income                     float64
# person_emp_exp                      int64
# person_home_ownership              object
# loan_amnt                         float64
# loan_intent                        object
# loan_int_rate                     float64
# loan_percent_income               float64
# cb_person_cred_hist_length        float64
# credit_score                        int64
# previous_loan_defaults_on_file     object
# loan_status                         int64
# dtype: object

# %%
#column loan amount average.
df['loan_amnt'].mean()
# Out:
# np.float64(9583.157555555556)

# %%
#to convert float to int
df['loan_amnt'].astype(int)
# Out:
# 0        35000
# 1         1000
# 2         5500
# 3        35000
# 4        35000
#          ...
# 44995    15000
# 44996     9000
# 44997     2771
# 44998    12000
# 44999     6665
# Name: loan_amnt, Length: 45000, dtype: int64

# %%
#greater than 30 small than 60
(df['person_age'] > 30 ) & (df['person_age'] < 60 )
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44995    False
# 44996     True
# 44997     True
# 44998    False
# 44999    False
# Name: person_age, Length: 45000, dtype: bool

# %%
df[(df['person_age'] > 30 ) & (df['person_age'] < 60 )]
# Out:
#        person_age person_gender  person_education  person_income  \
# 17833          32        female                 1      1440746.0
# 17834          34          male                 2      1138723.0
# 17836          33          male                 2        93638.0
# 17840          35        female                 3       778515.0
# 17842          31        female                 0        88456.0
# ...           ...           ...               ...            ...
# 44986          34          male                 2        41876.0
# 44987          34          male                 0        69210.0
# 44990          31          male                 0       136832.0
# 44996          37        female                 3        65800.0
# 44997          33          male                 3        56942.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 17833               6              MORTGAGE    12000.0            VENTURE
# ...

# %%
df['person_age'].sort_values()
# Out:
# 1313      20
# 12943     20
# 17196     20
# 11889     20
# 11902     20
#         ...
# 747      123
# 575      123
# 183      144
# 32297    144
# 81       144
# Name: person_age, Length: 45000, dtype: int64

# %%
#person_age in ascending
df['person_age'].sort_values(ascending=False)
# Out:
# 81       144
# 32297    144
# 183      144
# 575      123
# 747      123
#         ...
# 36423     20
# 5648      20
# 39292     20
# 9926      20
# 1313      20
# Name: person_age, Length: 45000, dtype: int64

# %%
#bivariate analysis
df.groupby('person_gender')['loan_amnt'].sum()
# Out:
# person_gender
# female    191682371.0
# male      239559719.0
# Name: loan_amnt, dtype: float64

# %%
#calculate sum person_income on the basis of education
df.groupby('person_education')['person_income'].sum()
# Out:
# person_education
# 0    5.618336e+08
# 1    9.604489e+08
# 2    1.067945e+09
# 3    9.699574e+08
# 4    5.417265e+07
# Name: person_income, dtype: float64

# %%
#calculate average person_income on the basis of education
df.groupby('person_education')['person_income'].mean()
# Out:
# person_education
# 0    80491.924355
# 1    80224.597645
# 2    79703.319725
# 3    80641.623628
# 4    87234.541063
# Name: person_income, dtype: float64

# %%
#average in ascending order
df.groupby('person_education')['person_income'].mean().sort_values(ascending=False)
# Out:
# person_education
# 4    87234.541063
# 3    80641.623628
# 0    80491.924355
# 1    80224.597645
# 2    79703.319725
# Name: person_income, dtype: float64

# %%
#Learning Functions
def num(a,b,c):
    result=a+b+c
    print(result)
    return result

a=num(a=5,c=1,b=10)
print('sum is',a) #diff than function's 'a'
# Out:
# 16
# sum is 16

# %%
df
# Out:
#        person_age person_gender  person_education  person_income  \
# 0              22        female                 0        71948.0
# 1              21        female                 1        12282.0
# 2              25        female                 1        12438.0
# 3              23        female                 2        79753.0
# 4              24          male                 0        66135.0
# ...           ...           ...               ...            ...
# 44995          27          male                 3        47971.0
# 44996          37        female                 3        65800.0
# 44997          33          male                 3        56942.0
# 44998          29          male                 2        33164.0
# 44999          24          male                 1        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
df['person_gender']=df['person_gender'].replace({'male':1, 'female':0})
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2300\967719336.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['person_gender']=df['person_gender'].replace({'male':1, 'female':0})

# %%
df
# Out:
#        person_age  person_gender  person_education  person_income  \
# 0              22              0                 0        71948.0
# 1              21              0                 1        12282.0
# 2              25              0                 1        12438.0
# 3              23              0                 2        79753.0
# 4              24              1                 0        66135.0
# ...           ...            ...               ...            ...
# 44995          27              1                 3        47971.0
# 44996          37              0                 3        65800.0
# 44997          33              1                 3        56942.0
# 44998          29              1                 2        33164.0
# 44999          24              1                 1        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
df['person_home_ownership']=df['person_home_ownership'].replace({'RENT':0, 'OWN':1, 'MORTGAGE':2, 'OTHER':3})
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2300\3341967788.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['person_home_ownership']=df['person_home_ownership'].replace({'RENT':0, 'OWN':1, 'MORTGAGE':2, 'OTHER':3})

# %%
df
# Out:
#        person_age  person_gender  person_education  person_income  \
# 0              22              0                 0        71948.0
# 1              21              0                 1        12282.0
# 2              25              0                 1        12438.0
# 3              23              0                 2        79753.0
# 4              24              1                 0        66135.0
# ...           ...            ...               ...            ...
# 44995          27              1                 3        47971.0
# 44996          37              0                 3        65800.0
# 44997          33              1                 3        56942.0
# 44998          29              1                 2        33164.0
# 44999          24              1                 1        51609.0
#
#        person_emp_exp  person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                      0    35000.0           PERSONAL
# ...

# %%
df['previous_loan_defaults_on_file']=df['previous_loan_defaults_on_file'].replace({'Yes':1, 'No':0})
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2300\2954893244.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['previous_loan_defaults_on_file']=df['previous_loan_defaults_on_file'].replace({'Yes':1, 'No':0})

# %%
df['loan_intent'].unique()
# Out:
# array(['PERSONAL', 'EDUCATION', 'MEDICAL', 'VENTURE', 'HOMEIMPROVEMENT',
#        'DEBTCONSOLIDATION'], dtype=object)

# %%
df['loan_intent']=df['loan_intent'].replace({'PERSONAL':0, 'EDUCATION':1, 'MEDICAL':2, 'VENTURE':3, 'HOMEIMPROVEMENT':4, 'DEBTCONSOLIDATION':5})
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2300\2001995044.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['loan_intent']=df['loan_intent'].replace({'PERSONAL':0, 'EDUCATION':1, 'MEDICAL':2, 'VENTURE':3, 'HOMEIMPROVEMENT':4, 'DEBTCONSOLIDATION':5})

# %%
df
# Out:
#        person_age  person_gender  person_education  person_income  \
# 0              22              0                 0        71948.0
# 1              21              0                 1        12282.0
# 2              25              0                 1        12438.0
# 3              23              0                 2        79753.0
# 4              24              1                 0        66135.0
# ...           ...            ...               ...            ...
# 44995          27              1                 3        47971.0
# 44996          37              0                 3        65800.0
# 44997          33              1                 3        56942.0
# 44998          29              1                 2        33164.0
# 44999          24              1                 1        51609.0
#
#        person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# 0                   0                      0    35000.0            0
# ...

# %%
#seperate data into independent and dependent variables
#y=mx+c y dependent to x !!
x=df.drop('loan_amnt',axis=1)
x
# Out:
#        person_age  person_gender  person_education  person_income  \
# 0              22              0                 0        71948.0
# 1              21              0                 1        12282.0
# 2              25              0                 1        12438.0
# 3              23              0                 2        79753.0
# 4              24              1                 0        66135.0
# ...           ...            ...               ...            ...
# 44995          27              1                 3        47971.0
# 44996          37              0                 3        65800.0
# 44997          33              1                 3        56942.0
# 44998          29              1                 2        33164.0
# 44999          24              1                 1        51609.0
#
#        person_emp_exp  person_home_ownership  loan_intent  loan_int_rate  \
# 0                   0                      0            0          16.02
# ...

# %%
y=df['loan_amnt']

# %%
x.shape #number of rows and column
# Out:
# (45000, 13)

# %%
y.shape
# Out:
# (45000,)

# %%
x.dtypes
# Out:
# person_age                          int64
# person_gender                       int64
# person_education                    int64
# person_income                     float64
# person_emp_exp                      int64
# person_home_ownership               int64
# loan_intent                         int64
# loan_int_rate                     float64
# loan_percent_income               float64
# cb_person_cred_hist_length        float64
# credit_score                        int64
# previous_loan_defaults_on_file      int64
# loan_status                         int64
# dtype: object

# %%
# !pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42) #20 percent #42 same split

# %%
x_train
# Out:
#        person_age  person_gender  person_education  person_income  \
# 25180          34              0                 2        97265.0
# 12555          25              1                 1        72953.0
# 29153          41              0                 0       322597.0
# 23838          27              1                 3        94232.0
# 35686          27              1                 0        84873.0
# ...           ...            ...               ...            ...
# 11284          26              1                 1        88451.0
# 44732          25              0                 1        34772.0
# 38158          33              0                 3        58317.0
# 860            26              1                 0       178602.0
# 15795          26              0                 1       210894.0
#
#        person_emp_exp  person_home_ownership  loan_intent  loan_int_rate  \
# 25180              11                      2            0          12.73
# ...

# %%
#linear eq
from sklearn.linear_model import LinearRegression

# %%
#variable lr_model
lr_model=LinearRegression()

# %%
#Train the model
lr_model.fit(x_train,y_train) #it fit model
# Out:
# LinearRegression()

# %%
#predict the model
predict=lr_model.predict(x_test)

# %%
predict
# Out:
# array([ 7289.47399789,  9265.09765239,  6529.67888031, ...,
#        11143.84504307, 12379.2203104 , 13232.82644352], shape=(9000,))

# %%
result=pd.DataFrame({'Actual_value':y_test,'predicted_by_model':predict})
result
# Out:
#        Actual_value  predicted_by_model
# 37979        7500.0         7289.473998
# 9911         9000.0         9265.097652
# 43386        5000.0         6529.678880
# 13822        5000.0         9271.239704
# 44810       10000.0        10448.563153
# ...             ...                 ...
# 14572       14000.0        10751.772509
# 30384        6725.0         8155.323423
# 36665       14000.0        11143.845043
# 30569        8000.0        12379.220310
# 5321         8500.0        13232.826444
#
# [9000 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score

# %%
r2_score=r2_score(y_test,predict)
r2_score
#how well a model (like a math equation) predicts the correct answers.
# Out:
# 0.5987850334091882

# %%
#MSE tells us if the model sometimes makes wildly bad predictions (even if most are decent).

# %%
mse=mean_squared_error(y_test,predict)
mse
# Out:
# 16149319.808292514

# %%
# MAE tells us the typical error size (easier to explain to non-experts).

# %%
mae=mean_absolute_error(y_test,predict)
mae
# Out:
# 2847.8442909179876

# %%
result.to_csv('result.csv',index=False)
